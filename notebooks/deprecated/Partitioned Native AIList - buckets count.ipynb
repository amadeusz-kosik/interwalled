# %%
# %run Common.ipynb

# %% [markdown]
# ## Results for 5 components

# %%
plot_dataset("partitioned-native-ailist-local", join_names=[
    "partitioned-native-ailist-benchmark-10-5", 
    "partitioned-native-ailist-benchmark-100-5", 
    "partitioned-native-ailist-benchmark-1000-5", 
    "partitioned-native-ailist-benchmark-10000-5"
])

# %%
plot_dataset("partitioned-native-ailist-local", join_names=[
    "partitioned-native-ailist-benchmark-10-10", 
    "partitioned-native-ailist-benchmark-100-10", 
    "partitioned-native-ailist-benchmark-1000-10", 
    "partitioned-native-ailist-benchmark-10000-10"
])

# %%
plot_dataset("partitioned-native-ailist-local", join_names=[
    "partitioned-native-ailist-benchmark-10-20", 
    "partitioned-native-ailist-benchmark-100-20", 
    "partitioned-native-ailist-benchmark-1000-20", 
    "partitioned-native-ailist-benchmark-10000-20"
])
