# %%
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
benchmark_results = pd.read_csv('data/benchmark-local.csv')

# %%
# Plotting 'Date' against 'Value'
plt.figure(figsize=(10, 6))
for category in df['Category']:
plt.plot(benchmark_results['dataSuite'], benchmark_results['elapsedTime'], label='Value over Time', color='blue')

# Adding labels and title
plt.xlabel('Date')
plt.ylabel('Value')
plt.title('Value over Time')
plt.legend()

# %%
def plot_dataset(dataset, test_dataset_name):
    plt.figure(figsize=(10, 6))

    for join_name in dataset['joinName'].unique():
        df_to_plot = dataset[dataset['joinName'] == join_name]
        plt.plot(df_to_plot['dataSize'], df_to_plot['elapsedTime'], label=join_name)
    
    # Adding labels and title
    plt.xlabel('Data size')
    plt.ylabel('Elapsed time')
    plt.legend()

# %%
print(benchmark_results.head)
# Out:
# <bound method NDFrame.head of            dataSuite  dataSize                           joinName  elapsedTime
# 0         one-to-all       100  SparkNativeBucketingBenchmark(10)          926
# 1      one-to-many-4       100  SparkNativeBucketingBenchmark(10)          329
# 2     one-to-many-64       100  SparkNativeBucketingBenchmark(10)          227
# 3    one-to-many-256       100  SparkNativeBucketingBenchmark(10)          165
# 4         one-to-one       100  SparkNativeBucketingBenchmark(10)          289
# ..               ...       ...                                ...          ...
# 170       one-to-all   1000000   PartitionedAIListBenchmark(1000)          662
# 171    one-to-many-4   1000000   PartitionedAIListBenchmark(1000)         1462
# 172   one-to-many-64   1000000   PartitionedAIListBenchmark(1000)          998
# 173  one-to-many-256   1000000   PartitionedAIListBenchmark(1000)          897
# ...

# %%
plot_dataset(benchmark_results[benchmark_results['dataSuite'] == 'one-to-all'], 'one-to-all')
